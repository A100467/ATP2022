# %%
#1
import random
def criaLista():
    lista = []
    N = int(input("insira o número de elementos da lista"))
    i = 0
    for i in range(N):
        x = random.randint(0,100)
        lista.append(x)
        i = i + 1
    return lista

#2
def leLista():
    lista = []
    i = 0 
    N = int(input("insira o número de elementos da lista"))
    while (i<N):
        x = int(input("insira um dos números da lista"))
        lista.append(x)
        i = i + 1
    return lista

#3
def somaLista():
    soma = 0 
    for i in lista:
        soma = soma + i
    return soma

#4
def mediaLista():
    soma = 0
    media = 0
    for i in lista:
        soma = soma + i
        media = soma / len(lista)
    return media

#5
def maiorLista():
    maior = lista[0]   
    for i in lista:    
        if i > maior:
            maior = i
    return maior 

#6
def menorLista():
    menor = lista[0]   
    for i in lista:    
        if i < menor:
            menor = i
    return menor

#7
def estaOrdenadaC():
    estaOrdenadaC = "Sim"
    for x in range(len(lista)-1):
        if lista[x] > lista[x+1]:              
            estaOrdenadaC = "Não"        
    return estaOrdenadaC

#8
def estaOrdenadaD():
    estaOrdenadaD = "Sim"
    for x in range(len(lista)-1):
        if lista[x] < lista[x+1]:
            estaOrdenadaD = "Não"
    return estaOrdenadaD

#9
def indiceElemento():
    elem = int(input("Insira o elemento pretendido"))
    for i in range(len(lista)):
        if i == elem:
            lista.index(elem)
            print("A posição do elemento é", lista.index(elem))
    if elem not in lista:
        print("O elemento nao está na lista")
    return i


opcao =  (""" 
        (1) Criar Lista 
        (2) Ler Lista
        (3) Soma
        (4) Média
        (5) Maior
        (6) Menor
        (7) estaOrdenada por ordem crescente
        (8) estaOrdenada por ordem decrescente
        (9) Procura um elemento
        (0) Sair  """)
print(opcao)
numero = int(input("Selecione a opção pretendida"))
lista = []
while numero != 0:
        if numero == 1:
            lista = criaLista()
            print("A sua lista é", lista )
            print(opcao)
            numero = int(input("Selecione a opção pretendida"))
        elif numero == 2:
            lista = leLista()
            print("A sua lista é", lista )
            print(opcao)
            numero = int(input("Selecione a opção pretendida"))
        elif numero == 3:
            somaLista()
            print("A soma da lista é", somaLista())
            print(opcao)
            numero = int(input("Selecione a opção pretendida"))
        elif numero == 4:
            mediaLista()
            print("A média da lista é", mediaLista())
            print(opcao)
            numero = int(input("Selecione a opção pretendida"))
        elif numero == 5:
            maiorLista()
            print("O maior número é", maiorLista())
            print(opcao)
            numero = int(input("Selecione a opção pretendida"))
        elif numero == 6:
            menorLista()
            print("O menor número é", menorLista())
            print(opcao)
            numero = int(input("Selecione a opção pretendida"))
        elif numero == 7:
            estaOrdenadaC()
            print(estaOrdenadaC())
            print(opcao)
            numero = int(input("Selecione a opção pretendida"))
        elif numero == 8:
            estaOrdenadaD()
            print(estaOrdenadaD())
            print(opcao)
            numero = int(input("Selecione a opção pretendida"))
        elif numero == 9:
            indiceElemento()
            print(indiceElemento())
            print(opcao)
            numero = int(input("Selecione a opção pretendida"))
if numero == 0:
    print("A sua lista é",lista)
# Out:
#
#         (1) Criar Lista
#         (2) Ler Lista
#         (3) Soma
#         (4) Média
#         (5) Maior
#         (6) Menor
#         (7) estaOrdenada por ordem crescente
#         (8) estaOrdenada por ordem decrescente
#         (9) Procura um elemento
#         (0) Sair
